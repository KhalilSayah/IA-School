# %%
import pygame as pg
import string
import tkinter as tk

def ajuster_taille_police(police, texte, taille_max):
    taille = taille_max
    while taille > 0:
        police_temp = pg.font.Font(None, taille)
        largeur, hauteur = police_temp.size(texte)
        if largeur <= taille_max and hauteur <= taille_max:
            return taille
        taille -= 1
    return 1

def afficher_message(message):
    root = tk.Tk()
    root.withdraw()
    tk.messagebox.showinfo("Instructions", message)
    root.destroy()

pg.init()

afficher_message("Bienvenue dans ma simulation de l'algorithme de Dijkstra !")

nombre_de_cellules = 20

info = pg.display.Info()
largeur_ecran = info.current_w - 50
hauteur_ecran = info.current_h - 50

cell_size = min(largeur_ecran, hauteur_ecran) // nombre_de_cellules
largeur_fenetre = cell_size * nombre_de_cellules
hauteur_fenetre = cell_size * nombre_de_cellules

ecran = pg.display.set_mode((largeur_fenetre, hauteur_fenetre), pg.RESIZABLE)

taille_max = cell_size
taille_police = ajuster_taille_police(pg.font.Font(None, taille_max), "A", taille_max)
police = pg.font.Font(None, taille_police)

debut = None
arrivee = None
obstacles = []

instructions = [
    "Cliquez sur une cellule pour définir le point de départ.",
    "Cliquez sur une autre cellule pour définir le point d'arrivée."
]

instruction_index = 0

afficher_message(instructions[0])

continuer = True
clic_gauche = False

while continuer:
    for event in pg.event.get():
        if event.type == pg.QUIT:
            continuer = False
        if event.type == pg.MOUSEBUTTONDOWN:
            if event.button == 1:
                clic_gauche = True
                x, y = event.pos
                col = x // cell_size
                ligne = y // cell_size

                if 0 <= col < nombre_de_cellules and 0 <= ligne < nombre_de_cellules:
                    if debut is None:
                        debut = (col, ligne)
                        afficher_message("Point de départ défini à ({}, {})".format(col, ligne))
                        instruction_index = 1
                    elif arrivee is None:
                        arrivee = (col, ligne)
                        afficher_message("Point d'arrivée défini à ({}, {})".format(col, ligne))
                        instruction_index = 2

        if event.type == pg.MOUSEBUTTONUP:
            if event.button == 1:
                clic_gauche = False

    ecran.fill((169, 169, 169))

    for x in range(0, largeur_fenetre, cell_size):
        pg.draw.line(ecran, (0, 0, 0), (x, 0), (x, hauteur_fenetre))
    for y in range(0, hauteur_fenetre, cell_size):
        pg.draw.line(ecran, (0, 0, 0), (0, y), (largeur_fenetre, y))

    for i in range(nombre_de_cellules):
        pg.draw.rect(ecran, (255, 255, 255), (0, i * cell_size, cell_size, cell_size))
        pg.draw.rect(ecran, (255, 255, 255), (i * cell_size, 0, cell_size, cell_size))

    for i in range(1, nombre_de_cellules):
        texte = police.render(str(i), True, (0, 0, 0))
        x = i * cell_size + cell_size // 2 - texte.get_width() // 2
        y = cell_size // 2 - texte.get_height() // 2
        ecran.blit(texte, (x, y))

    for i in range(nombre_de_cellules):
        lettre = string.ascii_uppercase[i]
        texte = police.render(lettre, True, (0, 0, 0))
        x = cell_size // 2 - texte.get_width() // 2
        y = (i + 1) * cell_size + cell_size // 2 - texte.get_height() // 2
        ecran.blit(texte, (x, y))

    if debut is not None:
        pg.draw.circle(ecran, (255, 0, 0), (debut[0] * cell_size + cell_size // 2, debut[1] * cell_size + cell_size // 2), cell_size // 4)

    if arrivee is not None:
        pg.draw.circle(ecran, (0, 255, 0), (arrivee[0] * cell_size + cell_size // 2, arrivee[1] * cell_size + cell_size // 2), cell_size // 4)

    if clic_gauche and debut is not None and arrivee is not None:
        mouse_x, mouse_y = pg.mouse.get_pos()
        col = mouse_x // cell_size
        ligne = mouse_y // cell_size
        if 0 <= col < nombre_de_cellules and 0 <= ligne < nombre_de_cellules:
            if (col, ligne) not in obstacles:
                obstacles.append((col, ligne))

    for obstacle in obstacles:
        pg.draw.rect(ecran, (128, 0, 128), (obstacle[0] * cell_size, obstacle[1] * cell_size, cell_size, cell_size))

    pg.display.flip()

pg.quit()
